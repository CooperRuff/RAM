# %%
pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\ctr22\appdata\local\programs\python\python311\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\ctr22\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\ctr22\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ctr22\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ctr22\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ctr22\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in c:\users\ctr22\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\ctr22\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pandas as pd

# Define the directory containing the trial sheets
directory = r'C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016'

# Create the main DataFrame
main = pd.DataFrame(columns=['Cell1', 'Cell2'])

# Function to process each trial sheet
def process_trial_sheet(trial_path):
    global main
    try:
        # Read the specified sheet, treating "N/A" and "None" as valid text
        trial = pd.read_excel(trial_path, sheet_name='Service Numbers', keep_default_na=False, na_values=[])
    except ValueError as e:
        print(f"Error reading '{trial_path}': {e}")
        return
    
    # Print the first few rows to ensure the file is read correctly
    print(f"Processing {trial_path}")
    print(trial.head())

    if trial.empty:
        print(f"No data found in '{trial_path}'. Skipping processing.")
        return
    
    if trial.shape[1] < 4:
        print(f"Error: '{trial_path}' does not have enough columns (need at least 4).")
        return
    
    # Create column names for cell3 and cell4 based on the filename
    column3 = f"{os.path.basename(trial_path)}_Cell3"
    column4 = f"{os.path.basename(trial_path)}_Cell4"
    
    for index, trial_row in trial.iterrows():
        if len(trial_row) < 4:
            print(f"Skipping row in '{trial_path}': Insufficient columns.")
            continue
        
        cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
        match = main[(main['Cell1'] == cell1) & (main['Cell2'] == cell2)]
        if not match.empty:
            # If there's a match, find the next open cell in the main DataFrame
            main_index = match.index[0]  # Use match.index[0] safely here
            print(f"Match found for Cell1: {cell1}, Cell2: {cell2} at index {main_index}")
            main.at[main_index, column3] = cell3
            main.at[main_index, column4] = cell4
        else:
            # If there's no match, add a new row
            print(f"No match found for Cell1: {cell1}, Cell2: {cell2}. Adding new row.")
            new_row = pd.DataFrame({
                'Cell1': [cell1],
                'Cell2': [cell2],
                column3: [cell3],
                column4: [cell4]
            })
            main = pd.concat([main, new_row], ignore_index=True)

# Check if the directory exists
if not os.path.isdir(directory):
    print(f"The directory {directory} does not exist.")
else:
    # Iterate through all trial sheets in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.xlsx'):
            trial_path = os.path.join(directory, filename)
            process_trial_sheet(trial_path)

    # Print the main DataFrame before filling NaNs
    print("Main DataFrame before filling NaNs:")
    print(main.head())

    # Fill NaNs in main with 0 only for numeric columns, leaving text values intact
    main.fillna(0, inplace=True)

    # Save the main DataFrame to an Excel file in the specified directory
    main_file_path = os.path.join(directory, 'main.xlsx')
    main.to_excel(main_file_path, index=False)

    print(f"The file has been saved as {main_file_path}")
# Out:
# Processing C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\Alamo_2016_Clinic Overview Report copy.xlsx
#      Area            ServiceName  Qty  TotalCost
# 0  Vision        Bifocal Glasses   89      17800
# 1  Vision               Eye Exam  298      29800
# 2  Vision           Mail Glasses   50          0
# 3  Vision                Readers   13        260
# 4  Vision  Single Vision Glasses  258      38700
# No match found for Cell1: Vision, Cell2: Bifocal Glasses. Adding new row.
# No match found for Cell1: Vision, Cell2: Eye Exam. Adding new row.
# No match found for Cell1: Vision, Cell2: Mail Glasses. Adding new row.
# No match found for Cell1: Vision, Cell2: Readers. Adding new row.
# No match found for Cell1: Vision, Cell2: Single Vision Glasses. Adding new row.
# No match found for Cell1: Vision, Cell2: Vision Referral. Adding new row.
# Processing C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\Bradenton_2016_Clinic Overview Report copy.xlsx
#      Area         ServiceName  Qty  TotalCost
# 0  Dental         Alveoplasty    1        412
# 1  Dental   Amalgam 1 Surface   12       1980
# 2  Dental  Amalgam 2 Surfaces    7       1505
# 3  Dental  Amalgam 3 Surfaces    2        510
# 4  Dental  Amalgam 4 Surfaces    1        356
# No match found for Cell1: Dental, Cell2: Alveoplasty. Adding new row.
# No match found for Cell1: Dental, Cell2: Amalgam 1 Surface. Adding new row.
# No match found for Cell1: Dental, Cell2: Amalgam 2 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Amalgam 3 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Amalgam 4 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#21). Adding new row.
# No match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#4). Adding new row.
# No match found for Cell1: Dental, Cell2: BiteWing (X-Ray). Adding new row.
# No match found for Cell1: Dental, Cell2: Blood Sugar. Adding new row.
# No match found for Cell1: Dental, Cell2: Clindamycin 150mg (#28). Adding new row.
# No match found for Cell1: Dental, Cell2: Composite 1 Surface. Adding new row.
# No match found for Cell1: Dental, Cell2: Composite 2 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Composite 3 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Composite 4 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Composite 5 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Composite 6 Surfaces. Adding new row.
# No match found for Cell1: Dental, Cell2: Dental Referral. Adding new row.
# No match found for Cell1: Dental, Cell2: Dental Triage Exam. Adding new row.
# No match found for Cell1: Dental, Cell2: Extraction - Simple. Adding new row.
# No match found for Cell1: Dental, Cell2: Extraction - Surgical. Adding new row.
# No match found for Cell1: Dental, Cell2: Fluoride. Adding new row.
# No match found for Cell1: Dental, Cell2: Gross Debridement. Adding new row.
# No match found for Cell1: Dental, Cell2: Ibuprofen 200mg (#60). Adding new row.
# No match found for Cell1: Dental, Cell2: Lidocaine. Adding new row.
# No match found for Cell1: Dental, Cell2: Marcaine. Adding new row.
# No match found for Cell1: Dental, Cell2: Mepivacaine / Carbocaine. Adding new row.
# No match found for Cell1: Dental, Cell2: Misc Procedures. Adding new row.
# No match found for Cell1: Dental, Cell2: PA-X (X-Ray). Adding new row.
# No match found for Cell1: Dental, Cell2: Prophy . Adding new row.
# No match found for Cell1: Dental, Cell2: Pulp Cap-Direct/Indirect. Adding new row.
# No match found for Cell1: Dental, Cell2: Pulpotomy. Adding new row.
# No match found for Cell1: Dental, Cell2: Recementation Crown. Adding new row.
# No match found for Cell1: Dental, Cell2: Root Planing. Adding new row.
# No match found for Cell1: Dental, Cell2: Rx To Be Filled Offsite. Adding new row.
# No match found for Cell1: Dental, Cell2: Scaling. Adding new row.
# No match found for Cell1: Dental, Cell2: Sealant. Adding new row.
# No match found for Cell1: Dental, Cell2: Septocaine. Adding new row.
# No match found for Cell1: Medical, Cell2: Blood Sugar. Adding new row.
# No match found for Cell1: Medical, Cell2: Breast Exams. Adding new row.
# No match found for Cell1: Medical, Cell2: CMP - Complete Metabolic Panel. Adding new row.
# No match found for Cell1: Medical, Cell2: Diabetes Screening (A1C). Adding new row.
# No match found for Cell1: Medical, Cell2: Ear Wax Removal. Adding new row.
# No match found for Cell1: Medical, Cell2: Education - Diabetes. Adding new row.
# No match found for Cell1: Medical, Cell2: Education - Heart/Stroke. Adding new row.
# No match found for Cell1: Medical, Cell2: Education - Nutrition/Food Safety. Adding new row.
# No match found for Cell1: Medical, Cell2: Education - Smoking. Adding new row.
# No match found for Cell1: Medical, Cell2: Education - Weight Loss/BMI. Adding new row.
# No match found for Cell1: Medical, Cell2: Flu Shot. Adding new row.
# No match found for Cell1: Medical, Cell2: Foot Care. Adding new row.
# No match found for Cell1: Medical, Cell2: Hearing Exam. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Complete Blood Count. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Hepatitis C Quantitation. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Lipoprotein Panel. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Pap Smear. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Pregnancy Test. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - PSA. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Quantitative HIV. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Thyroid Stimulating Panel. Adding new row.
# No match found for Cell1: Medical, Cell2: Lab - Urinalysis, Complete. Adding new row.
# No match found for Cell1: Medical, Cell2: Mammogram. Adding new row.
# No match found for Cell1: Medical, Cell2: Medical Exam. Adding new row.
# No match found for Cell1: Medical, Cell2: Medical Referral. Adding new row.
# No match found for Cell1: Medical, Cell2: Misc Procedures. Adding new row.
# No match found for Cell1: Medical, Cell2: Osteopathic Manipulation. Adding new row.
# No match found for Cell1: Medical, Cell2: Physical Exam-General. Adding new row.
# No match found for Cell1: Medical, Cell2: Physical Exam-Women's. Adding new row.
# No match found for Cell1: Medical, Cell2: Rx Dispensed Onsite. Adding new row.
# No match found for Cell1: Medical, Cell2: Rx Written for Offsite. Adding new row.
# No match found for Cell1: Medical, Cell2: Vaccine - Miscellaneous. Adding new row.
# No match found for Cell1: Medical, Cell2: Wound Care. Adding new row.
# Match found for Cell1: Vision, Cell2: Bifocal Glasses at index 0
# No match found for Cell1: Vision, Cell2: Blood Sugar. Adding new row.
# Match found for Cell1: Vision, Cell2: Eye Exam at index 1
# Match found for Cell1: Vision, Cell2: Readers at index 3
# Match found for Cell1: Vision, Cell2: Single Vision Glasses at index 4
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# Processing C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\Elkview_2016_Clinic Overview Report copy.xlsx
#      Area         ServiceName  Qty  TotalCost
# 0  Dental         Alveoplasty    2        824
# 1  Dental   Amalgam 1 Surface    3        495
# 2  Dental  Amalgam 2 Surfaces    5       1075
# 3  Dental  Amalgam 3 Surfaces    4       1020
# 4  Dental  Amalgam 4 Surfaces    1        356
# Match found for Cell1: Dental, Cell2: Alveoplasty at index 6
# Match found for Cell1: Dental, Cell2: Amalgam 1 Surface at index 7
# Match found for Cell1: Dental, Cell2: Amalgam 2 Surfaces at index 8
# Match found for Cell1: Dental, Cell2: Amalgam 3 Surfaces at index 9
# Match found for Cell1: Dental, Cell2: Amalgam 4 Surfaces at index 10
# Match found for Cell1: Dental, Cell2: BiteWing (X-Ray) at index 13
# Match found for Cell1: Dental, Cell2: Blood Sugar at index 14
# Match found for Cell1: Dental, Cell2: Composite 1 Surface at index 16
# Match found for Cell1: Dental, Cell2: Composite 2 Surfaces at index 17
# Match found for Cell1: Dental, Cell2: Composite 3 Surfaces at index 18
# Match found for Cell1: Dental, Cell2: Composite 4 Surfaces at index 19
# Match found for Cell1: Dental, Cell2: Composite 5 Surfaces at index 20
# Match found for Cell1: Dental, Cell2: Composite 6 Surfaces at index 21
# Match found for Cell1: Dental, Cell2: Dental Triage Exam at index 23
# Match found for Cell1: Dental, Cell2: Extraction - Simple at index 24
# Match found for Cell1: Dental, Cell2: Extraction - Surgical at index 25
# Match found for Cell1: Dental, Cell2: Fluoride at index 26
# Match found for Cell1: Dental, Cell2: Gross Debridement at index 27
# Match found for Cell1: Dental, Cell2: Lidocaine at index 29
# Match found for Cell1: Dental, Cell2: Marcaine at index 30
# Match found for Cell1: Dental, Cell2: Mepivacaine / Carbocaine at index 31
# Match found for Cell1: Dental, Cell2: PA-X (X-Ray) at index 33
# Match found for Cell1: Dental, Cell2: Prophy  at index 34
# Match found for Cell1: Dental, Cell2: Pulp Cap-Direct/Indirect at index 35
# Match found for Cell1: Dental, Cell2: Root Planing at index 38
# Match found for Cell1: Dental, Cell2: Scaling at index 40
# Match found for Cell1: Dental, Cell2: Septocaine at index 42
# Match found for Cell1: Medical, Cell2: Blood Sugar at index 43
# Match found for Cell1: Medical, Cell2: Breast Exams at index 44
# No match found for Cell1: Medical, Cell2: Chest X-Ray. Adding new row.
# No match found for Cell1: Medical, Cell2: Chiropractic. Adding new row.
# Match found for Cell1: Medical, Cell2: Education - Diabetes at index 48
# Match found for Cell1: Medical, Cell2: Education - Nutrition/Food Safety at index 50
# Match found for Cell1: Medical, Cell2: Education - Smoking at index 51
# Match found for Cell1: Medical, Cell2: Education - Weight Loss/BMI at index 52
# Match found for Cell1: Medical, Cell2: Flu Shot at index 53
# Match found for Cell1: Medical, Cell2: Foot Care at index 54
# Match found for Cell1: Medical, Cell2: Lab - Pap Smear at index 59
# Match found for Cell1: Medical, Cell2: Lab - Urinalysis, Complete at index 64
# No match found for Cell1: Medical, Cell2: Lab - Urine Chemstrip. Adding new row.
# Match found for Cell1: Medical, Cell2: Medical Exam at index 66
# Match found for Cell1: Medical, Cell2: Medical Referral at index 67
# Match found for Cell1: Medical, Cell2: Physical Exam-General at index 70
# Match found for Cell1: Medical, Cell2: Physical Exam-Women's at index 71
# Match found for Cell1: Medical, Cell2: Rx Dispensed Onsite at index 72
# Match found for Cell1: Medical, Cell2: Vaccine - Miscellaneous at index 74
# Match found for Cell1: Medical, Cell2: Wound Care at index 75
# Match found for Cell1: Vision, Cell2: Bifocal Glasses at index 0
# Match found for Cell1: Vision, Cell2: Blood Sugar at index 76
# Match found for Cell1: Vision, Cell2: Eye Exam at index 1
# Match found for Cell1: Vision, Cell2: Mail Glasses at index 2
# Match found for Cell1: Vision, Cell2: Readers at index 3
# Match found for Cell1: Vision, Cell2: Single Vision Glasses at index 4
# Match found for Cell1: Vision, Cell2: Vision Referral at index 5
# Processing C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\GardenGrove_2016_Clinic Overview Report copy.xlsx
#      Area              ServiceName  Qty  TotalCost
# 0  Dental        Amalgam 1 Surface    1        165
# 1  Dental       Amalgam 2 Surfaces    3        645
# 2  Dental       Amalgam 3 Surfaces    2        510
# 3  Dental       Amalgam 4 Surfaces    3       1068
# 4  Dental  Amoxicillin 500mg (#21)    3          9
# Match found for Cell1: Dental, Cell2: Amalgam 1 Surface at index 7
# Match found for Cell1: Dental, Cell2: Amalgam 2 Surfaces at index 8
# Match found for Cell1: Dental, Cell2: Amalgam 3 Surfaces at index 9
# Match found for Cell1: Dental, Cell2: Amalgam 4 Surfaces at index 10
# Match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#21) at index 11
# Match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#4) at index 12
# Match found for Cell1: Dental, Cell2: BiteWing (X-Ray) at index 13
# Match found for Cell1: Dental, Cell2: Blood Sugar at index 14
# Match found for Cell1: Dental, Cell2: Composite 1 Surface at index 16
# Match found for Cell1: Dental, Cell2: Composite 2 Surfaces at index 17
# Match found for Cell1: Dental, Cell2: Composite 3 Surfaces at index 18
# Match found for Cell1: Dental, Cell2: Composite 4 Surfaces at index 19
# Match found for Cell1: Dental, Cell2: Composite 5 Surfaces at index 20
# Match found for Cell1: Dental, Cell2: Dental Referral at index 22
# Match found for Cell1: Dental, Cell2: Dental Triage Exam at index 23
# Match found for Cell1: Dental, Cell2: Extraction - Simple at index 24
# Match found for Cell1: Dental, Cell2: Extraction - Surgical at index 25
# Match found for Cell1: Dental, Cell2: Fluoride at index 26
# Match found for Cell1: Dental, Cell2: Gross Debridement at index 27
# Match found for Cell1: Dental, Cell2: Ibuprofen 200mg (#60) at index 28
# Match found for Cell1: Dental, Cell2: Lidocaine at index 29
# Match found for Cell1: Dental, Cell2: Mepivacaine / Carbocaine at index 31
# Match found for Cell1: Dental, Cell2: PA-X (X-Ray) at index 33
# Match found for Cell1: Dental, Cell2: Prophy  at index 34
# Match found for Cell1: Dental, Cell2: Root Planing at index 38
# Match found for Cell1: Dental, Cell2: Rx To Be Filled Offsite at index 39
# Match found for Cell1: Dental, Cell2: Scaling at index 40
# Match found for Cell1: Dental, Cell2: Septocaine at index 42
# Match found for Cell1: Medical, Cell2: Chiropractic at index 78
# Match found for Cell1: Medical, Cell2: Diabetes Screening (A1C) at index 46
# Match found for Cell1: Medical, Cell2: Education - Diabetes at index 48
# Match found for Cell1: Medical, Cell2: Education - Smoking at index 51
# Match found for Cell1: Medical, Cell2: Flu Shot at index 53
# Match found for Cell1: Medical, Cell2: Lab - Pap Smear at index 59
# Match found for Cell1: Medical, Cell2: Medical Exam at index 66
# Match found for Cell1: Medical, Cell2: Medical Referral at index 67
# Match found for Cell1: Medical, Cell2: Physical Exam-General at index 70
# Match found for Cell1: Medical, Cell2: Rx Dispensed Onsite at index 72
# Match found for Cell1: Medical, Cell2: Rx Written for Offsite at index 73
# Match found for Cell1: Vision, Cell2: Bifocal Glasses at index 0
# Match found for Cell1: Vision, Cell2: Blood Sugar at index 76
# Match found for Cell1: Vision, Cell2: Eye Exam at index 1
# Match found for Cell1: Vision, Cell2: Readers at index 3
# No match found for Cell1: Vision, Cell2: Rx Medication To Be Filled Offsite. Adding new row.
# No match found for Cell1: Vision, Cell2: Screening Only. Adding new row.
# Match found for Cell1: Vision, Cell2: Single Vision Glasses at index 4
# No match found for Cell1: Vision, Cell2: Spot Test. Adding new row.
# Match found for Cell1: Vision, Cell2: Vision Referral at index 5
# Processing C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\Grundy_2016_Clinic Overview Report copy.xlsx
#      Area                ServiceName  Qty  TotalCost
# 0  Dental  Acetaminophen 325mg (#15)   15         30
# 1  Dental   Acetaminophen 500mg (#4)    4          4
# 2  Dental                Alveoplasty    5       2060
# 3  Dental          Amalgam 1 Surface   20       3300
# 4  Dental         Amalgam 2 Surfaces    5       1075
# No match found for Cell1: Dental, Cell2: Acetaminophen 325mg (#15). Adding new row.
# No match found for Cell1: Dental, Cell2: Acetaminophen 500mg (#4). Adding new row.
# Match found for Cell1: Dental, Cell2: Alveoplasty at index 6
# Match found for Cell1: Dental, Cell2: Amalgam 1 Surface at index 7
# Match found for Cell1: Dental, Cell2: Amalgam 2 Surfaces at index 8
# Match found for Cell1: Dental, Cell2: Amalgam 3 Surfaces at index 9
# Match found for Cell1: Dental, Cell2: Amalgam 4 Surfaces at index 10
# Match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#21) at index 11
# Match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#4) at index 12
# Match found for Cell1: Dental, Cell2: BiteWing (X-Ray) at index 13
# Match found for Cell1: Dental, Cell2: Blood Sugar at index 14
# No match found for Cell1: Dental, Cell2: Clindamycin 150mg (#4). Adding new row.
# Match found for Cell1: Dental, Cell2: Composite 1 Surface at index 16
# Match found for Cell1: Dental, Cell2: Composite 2 Surfaces at index 17
# Match found for Cell1: Dental, Cell2: Composite 3 Surfaces at index 18
# Match found for Cell1: Dental, Cell2: Composite 4 Surfaces at index 19
# Match found for Cell1: Dental, Cell2: Composite 5 Surfaces at index 20
# Match found for Cell1: Dental, Cell2: Composite 6 Surfaces at index 21
# No match found for Cell1: Dental, Cell2: Core Buildup. Adding new row.
# Match found for Cell1: Dental, Cell2: Dental Referral at index 22
# Match found for Cell1: Dental, Cell2: Dental Triage Exam at index 23
# No match found for Cell1: Dental, Cell2: Denture Repair. Adding new row.
# Match found for Cell1: Dental, Cell2: Extraction - Simple at index 24
# Match found for Cell1: Dental, Cell2: Extraction - Surgical at index 25
# Match found for Cell1: Dental, Cell2: Fluoride at index 26
# Match found for Cell1: Dental, Cell2: Gross Debridement at index 27
# No match found for Cell1: Dental, Cell2: Ibuprofen 200mg (#4). Adding new row.
# Match found for Cell1: Dental, Cell2: Ibuprofen 200mg (#60) at index 28
# No match found for Cell1: Dental, Cell2: Ibuprofen 600mg (#15). Adding new row.
# No match found for Cell1: Dental, Cell2: Ibuprofen 800mg (#12). Adding new row.
# No match found for Cell1: Dental, Cell2: Ibuprofen 800mg (#15). Adding new row.
# Match found for Cell1: Dental, Cell2: Lidocaine at index 29
# Match found for Cell1: Dental, Cell2: Marcaine at index 30
# Match found for Cell1: Dental, Cell2: Mepivacaine / Carbocaine at index 31
# Match found for Cell1: Dental, Cell2: PA-X (X-Ray) at index 33
# No match found for Cell1: Dental, Cell2: Panorex (X-Ray). Adding new row.
# No match found for Cell1: Dental, Cell2: Prophy. Adding new row.
# Match found for Cell1: Dental, Cell2: Pulp Cap-Direct/Indirect at index 35
# No match found for Cell1: Dental, Cell2: Root Canal. Adding new row.
# Match found for Cell1: Dental, Cell2: Root Planing at index 38
# Match found for Cell1: Dental, Cell2: Rx To Be Filled Offsite at index 39
# Match found for Cell1: Dental, Cell2: Scaling at index 40
# Match found for Cell1: Dental, Cell2: Septocaine at index 42
# Match found for Cell1: Medical, Cell2: Blood Sugar at index 43
# Match found for Cell1: Medical, Cell2: CMP - Complete Metabolic Panel at index 45
# Match found for Cell1: Medical, Cell2: Diabetes Screening (A1C) at index 46
# Match found for Cell1: Medical, Cell2: Education - Diabetes at index 48
# Match found for Cell1: Medical, Cell2: Education - Heart/Stroke at index 49
# Match found for Cell1: Medical, Cell2: Education - Nutrition/Food Safety at index 50
# Match found for Cell1: Medical, Cell2: Education - Smoking at index 51
# Match found for Cell1: Medical, Cell2: Education - Weight Loss/BMI at index 52
# No match found for Cell1: Medical, Cell2: EKG. Adding new row.
# Match found for Cell1: Medical, Cell2: Flu Shot at index 53
# Match found for Cell1: Medical, Cell2: Hearing Exam at index 55
# No match found for Cell1: Medical, Cell2: Hepatic Function Panel. Adding new row.
# Match found for Cell1: Medical, Cell2: Lab - Complete Blood Count at index 56
# Match found for Cell1: Medical, Cell2: Lab - Hepatitis C Quantitation at index 57
# Match found for Cell1: Medical, Cell2: Lab - Lipoprotein Panel at index 58
# Match found for Cell1: Medical, Cell2: Lab - Pap Smear at index 59
# Match found for Cell1: Medical, Cell2: Lab - Pregnancy Test at index 60
# ...
# Match found for Cell1: Dental, Cell2: Amalgam 3 Surfaces at index 9
# Match found for Cell1: Dental, Cell2: Amalgam 4 Surfaces at index 10
# Match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#21) at index 11
# No match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#30). Adding new row.
# Match found for Cell1: Dental, Cell2: Amoxicillin 500mg (#4) at index 12
# Match found for Cell1: Dental, Cell2: BiteWing (X-Ray) at index 13
# Match found for Cell1: Dental, Cell2: Clindamycin 150mg (#28) at index 15
# Match found for Cell1: Dental, Cell2: Composite 1 Surface at index 16
# Match found for Cell1: Dental, Cell2: Composite 2 Surfaces at index 17
# Match found for Cell1: Dental, Cell2: Composite 3 Surfaces at index 18
# Match found for Cell1: Dental, Cell2: Composite 4 Surfaces at index 19
# Match found for Cell1: Dental, Cell2: Composite 5 Surfaces at index 20
# Match found for Cell1: Dental, Cell2: Composite 6 Surfaces at index 21
# Match found for Cell1: Dental, Cell2: Dental Triage Exam at index 23
# Match found for Cell1: Dental, Cell2: Extraction - Simple at index 24
# Match found for Cell1: Dental, Cell2: Extraction - Surgical at index 25
# Match found for Cell1: Dental, Cell2: Fluoride at index 26
# Match found for Cell1: Dental, Cell2: Gross Debridement at index 27
# Match found for Cell1: Dental, Cell2: Ibuprofen 200mg (#60) at index 28
# Match found for Cell1: Dental, Cell2: Lidocaine at index 29
# Match found for Cell1: Dental, Cell2: Marcaine at index 30
# Match found for Cell1: Dental, Cell2: Mepivacaine / Carbocaine at index 31
# No match found for Cell1: Dental, Cell2: Open & Drain. Adding new row.
# Match found for Cell1: Dental, Cell2: PA-X (X-Ray) at index 33
# Match found for Cell1: Dental, Cell2: Panorex (X-Ray) at index 92
# Match found for Cell1: Dental, Cell2: Prophy  at index 34
# Match found for Cell1: Dental, Cell2: Pulp Cap-Direct/Indirect at index 35
# Match found for Cell1: Dental, Cell2: Root Planing at index 38
# Match found for Cell1: Dental, Cell2: Scaling at index 40
# Match found for Cell1: Dental, Cell2: Septocaine at index 42
# Match found for Cell1: Medical, Cell2: Blood Sugar at index 43
# No match found for Cell1: Medical, Cell2: Bone Density Testing. Adding new row.
# Match found for Cell1: Medical, Cell2: Breast Exams at index 44
# Match found for Cell1: Medical, Cell2: Diabetes Screening (A1C) at index 46
# Match found for Cell1: Medical, Cell2: Education - Diabetes at index 48
# Match found for Cell1: Medical, Cell2: Education - Heart/Stroke at index 49
# Match found for Cell1: Medical, Cell2: Education - Smoking at index 51
# Match found for Cell1: Medical, Cell2: EKG at index 95
# Match found for Cell1: Medical, Cell2: Flu Shot at index 53
# Match found for Cell1: Medical, Cell2: Lab - Complete Blood Count at index 56
# No match found for Cell1: Medical, Cell2: Lab - GC/Chlamydia Probe. Adding new row.
# Match found for Cell1: Medical, Cell2: Lab - Lipoprotein Panel at index 58
# Match found for Cell1: Medical, Cell2: Lab - Pap Smear at index 59
# Match found for Cell1: Medical, Cell2: Mammogram at index 65
# Match found for Cell1: Medical, Cell2: Medical Exam at index 66
# Match found for Cell1: Medical, Cell2: Medical Referral at index 67
# Match found for Cell1: Medical, Cell2: Misc Procedures at index 68
# Match found for Cell1: Medical, Cell2: Physical Exam-Women's at index 71
# Match found for Cell1: Medical, Cell2: Rx Dispensed Onsite at index 72
# Match found for Cell1: Medical, Cell2: Rx Written for Offsite at index 73
# Match found for Cell1: Medical, Cell2: Vaccine - Miscellaneous at index 74
# Match found for Cell1: Vision, Cell2: Bifocal Glasses at index 0
# Match found for Cell1: Vision, Cell2: Blood Sugar at index 76
# Match found for Cell1: Vision, Cell2: Eye Exam at index 1
# Match found for Cell1: Vision, Cell2: Mail Glasses at index 2
# Match found for Cell1: Vision, Cell2: Readers at index 3
# Match found for Cell1: Vision, Cell2: Single Vision Glasses at index 4
# Match found for Cell1: Vision, Cell2: Vision Referral at index 5
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# Processing C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\VMC_2016_Clinic Overview Report copy.xlsx
#      Area            ServiceName  Qty  TotalCost
# 0  Vision        Bifocal Glasses   73      14600
# 1  Vision               Eye Exam  138      13800
# 2  Vision                Readers    4         80
# 3  Vision  Single Vision Glasses   67      10050
# Match found for Cell1: Vision, Cell2: Bifocal Glasses at index 0
# Match found for Cell1: Vision, Cell2: Eye Exam at index 1
# Match found for Cell1: Vision, Cell2: Readers at index 3
# Match found for Cell1: Vision, Cell2: Single Vision Glasses at index 4
# Main DataFrame before filling NaNs:
#     Cell1                  Cell2  \
# 0  Vision        Bifocal Glasses
# 1  Vision               Eye Exam
# 2  Vision           Mail Glasses
# 3  Vision                Readers
# 4  Vision  Single Vision Glasses
#
#    Alamo_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                               89.0
# 1                                              298.0
# 2                                               50.0
# 3                                               13.0
# 4                                              258.0
#
#    Alamo_2016_Clinic Overview Report copy.xlsx_Cell4  \
# 0                                            17800.0
# 1                                            29800.0
# 2                                                0.0
# 3                                              260.0
# 4                                            38700.0
#
#    Bradenton_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                               33.0
# 1                                              285.0
# 2                                                NaN
# 3                                                3.0
# 4                                              344.0
#
#    Bradenton_2016_Clinic Overview Report copy.xlsx_Cell4  \
# 0                                             6600.0
# 1                                            28500.0
# 2                                                NaN
# 3                                               60.0
# 4                                            51600.0
#
#    Elkview_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                               82.0
# 1                                              277.0
# 2                                               72.0
# 3                                                5.0
# 4                                              267.0
#
#    Elkview_2016_Clinic Overview Report copy.xlsx_Cell4  \
# 0                                            16400.0
# 1                                            27700.0
# 2                                                0.0
# 3                                              100.0
# 4                                            40050.0
#
#    GardenGrove_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                              292.0
# 1                                              442.0
# 2                                                NaN
# 3                                               18.0
# 4                                              121.0
#
#    GardenGrove_2016_Clinic Overview Report copy.xlsx_Cell4  \
# 0                                            58400.0
# 1                                            44200.0
# 2                                                NaN
# 3                                              360.0
# 4                                            18150.0
#
#    Grundy_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                              112.0
# 1                                              222.0
# 2                                               44.0
# 3                                                7.0
# 4                                              201.0
#
#    Grundy_2016_Clinic Overview Report copy.xlsx_Cell4  \
# 0                                            22400.0
# 1                                            22200.0
# 2                                                0.0
# 3                                              140.0
# 4                                            30150.0
#
#    JohnsonCity_Stand Down_Clinic Overview Report8 copy.xlsx_Cell3  \
# 0                                               22.0
# 1                                               32.0
# 2                                               12.0
# 3                                                3.0
# 4                                               20.0
#
#    JohnsonCity_Stand Down_Clinic Overview Report8 copy.xlsx_Cell4  \
# 0                                             4400.0
# 1                                             3200.0
# 2                                                0.0
# 3                                               60.0
# 4                                             3000.0
#
#    Memphis_2016_Clinic Overview Report2 copy.xlsx_Cell3  \
# 0                                               75.0
# 1                                              218.0
# 2                                               15.0
# 3                                                1.0
# 4                                              107.0
#
#    Memphis_2016_Clinic Overview Report2 copy.xlsx_Cell4  \
# 0                                            15000.0
# 1                                            21800.0
# 2                                                0.0
# 3                                               20.0
# 4                                            16050.0
#
#    Milton_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                               84.0
# 1                                              203.0
# 2                                                8.0
# 3                                                1.0
# 4                                              116.0
#
#    Milton_2016_Clinic Overview Report copy.xlsx_Cell4  \
# 0                                            16800.0
# 1                                            20300.0
# 2                                                0.0
# 3                                               20.0
# 4                                            17400.0
#
#    VMC_2016_Clinic Overview Report copy.xlsx_Cell3  \
# 0                                             73.0
# 1                                            138.0
# 2                                              NaN
# 3                                              4.0
# 4                                             67.0
#
#    VMC_2016_Clinic Overview Report copy.xlsx_Cell4
# 0                                          14600.0
# 1                                          13800.0
# 2                                              NaN
# 3                                             80.0
# 4                                          10050.0
# The file has been saved as C:\Users\ctr22\Downloads\RAM2016Stats\Patient Answers 2016\main.xlsx
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
# C:\Users\ctr22\AppData\Local\Temp\ipykernel_43340\2835967438.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell1, cell2, cell3, cell4 = trial_row[0], trial_row[1], trial_row[2], trial_row[3]
